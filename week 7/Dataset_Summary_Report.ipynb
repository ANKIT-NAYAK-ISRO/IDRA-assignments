# %% [markdown]
# # Dataset Summary Report Using Python and Pandas
#
# ## Objective
#
# The objective of this assignment is to load a CSV dataset into a Pandas DataFrame and explore its basic structure and characteristics. The analysis demonstrates how to inspect the first and last few rows, view random samples, check the dataset's shape, columns, index, and data types, and generate descriptive statistics using `info()` and `describe()`. Basic observations about the dataset, including its size, features, data types, and missing values, are also presented.

# %% [markdown]
# ## 1. Import Required Library

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load the Dataset

# %%
df = pd.read_csv("Day7_Student_Dataset.csv")

print("Dataset loaded successfully!")

# %% [markdown]
# ## 3. Display the First Few Rows

# %%
df.head()

# %% [markdown]
# ## 4. Display the Last Few Rows

# %%
df.tail()

# %% [markdown]
# ## 5. Display Random Samples

# %%
df.sample(5, random_state=42)

# %% [markdown]
# ## 6. Check the Shape of the Dataset

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
print("Dataset Shape:", df.shape)

# %% [markdown]
# ## 7. View Column Names

# %%
print("Available Features:")
print(df.columns.tolist())

# %% [markdown]
# ## 8. View Dataset Index

# %%
print(df.index)

# %% [markdown]
# ## 9. Check Data Types

# %%
print(df.dtypes)

# %% [markdown]
# ## 10. Dataset Information

# %%
df.info()

# %% [markdown]
# ## 11. Generate Descriptive Statistics

# %%
df.describe()

# %% [markdown]
# ## 12. Check Missing Values

# %%
print(df.isnull().sum())

# %% [markdown]
# ## 13. Additional Basic Summary

# %%
print("Total Missing Values:", df.isnull().sum().sum())
print("\nNumber of Unique Values in Each Column:")
print(df.nunique())

# %% [markdown]
# ## Key Observations
#
# 1. The Student Dataset contains **25 rows and 7 columns**.
# 2. The available features are:
#    - Student_ID
#    - Name
#    - Age
#    - Course
#    - Marks
#    - Attendance_Percentage
#    - City
# 3. The dataset contains a combination of numerical and categorical data types.
# 4. `Student_ID` and `Age` are stored as integer (`int64`) values.
# 5. `Marks` and `Attendance_Percentage` are stored as floating-point (`float64`) values.
# 6. `Name`, `Course`, and `City` are categorical/text columns stored as object data types.
# 7. Missing values are present in the dataset:
#    - Marks: 1 missing value
#    - Attendance_Percentage: 1 missing value
#    - City: 1 missing value
# 8. No missing values are present in Student_ID, Name, Age, or Course.
# 9. The `describe()` function provides useful statistical information for the numerical columns, including count, mean, standard deviation, minimum, maximum, and quartile values.
# 10. The dataset can be further processed by handling the missing values before performing advanced analysis.

# %% [markdown]
# ## Conclusion
#
# The Student Dataset was successfully loaded and explored using Python and Pandas. Various functions such as `head()`, `tail()`, `sample()`, `shape`, `columns`, `index`, `dtypes`, `info()`, and `describe()` were used to understand the dataset's structure and characteristics. The dataset contains 25 student records with 7 features and includes both numerical and categorical data. A small number of missing values were identified in the Marks, Attendance_Percentage, and City columns. This summary provides a clear overview of the dataset and prepares it for further data cleaning and analysis.
